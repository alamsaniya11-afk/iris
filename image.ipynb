# %% [markdown]
# <a href="https://colab.research.google.com/github/alamsaniya11-afk/iris/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_path="/content/saniya passport image .jpeg"

# %%
img =cv2.imread(img_path)

# %%
img_rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_grey =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title('original image(RGB)')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(img_grey,cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.tight_layout()
plt.show()
